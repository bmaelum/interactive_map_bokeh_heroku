# %% [markdown]
# # Interactive Map using Python

# %%
# https://towardsdatascience.com/how-to-create-an-interactive-geographic-map-using-python-and-bokeh-12981ca0b567

# %%
# Import libraries
import pandas as pd
import numpy as np
import math

import geopandas
import json

from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar, NumeralTickFormatter
from bokeh.palettes import brewer

from bokeh.io.doc import curdoc
from bokeh.models import Slider, HoverTool, Select
from bokeh.layouts import widgetbox, row, column

# %% [markdown]
# ### Import cleaned data

# %%
neighborhood_data = pd.read_csv('https://raw.githubusercontent.com/JimKing100/SF_Real_Estate_Live/master/data/neighborhood_data.csv')

# %% [markdown]
# ## Geodata

# %%
# Read the geojson map file for Realtor Neighborhoods into a GeoDataframe object
sf = geopandas.read_file('https://raw.githubusercontent.com/JimKing100/SF_Real_Estate_Live/master/data/Realtor%20Neighborhoods.geojson')

# Set the Coordinate Referance System (crs) for projections
# ESPG code 4326 is also referred to as WGS84 lat-long projection
sf.crs = {'init': 'epsg:4326'}

# Rename columns in geojson map file
sf = sf.rename(columns={'geometry': 'geometry','nbrhood':'neighborhood_name', 'nid': 'subdist_no'}).set_geometry('geometry')

# Change neighborhood id (subdist_no) for correct code for Mount Davidson Manor and for parks
sf.loc[sf['neighborhood_name'] == 'Mount Davidson Manor', 'subdist_no'] = '4n'
sf.loc[sf['neighborhood_name'] == 'Golden Gate Park', 'subdist_no'] = '12a'
sf.loc[sf['neighborhood_name'] == 'Presidio', 'subdist_no'] = '12b'
sf.loc[sf['neighborhood_name'] == 'Lincoln Park', 'subdist_no'] = '12c'

sf.sort_values(by=['subdist_no'])
# Out:
#                    neighborhood_name subdist_no                  sfar_distr  \
# 3                            Bayview        10a     District 10 - Southeast
# 11                    Crocker Amazon        10b     District 10 - Southeast
# 16                         Excelsior        10c     District 10 - Southeast
# 57                     Outer Mission        10d     District 10 - Southeast
# 79                 Visitacion Valley        10e     District 10 - Southeast
# 65                           Portola        10f     District 10 - Southeast
# 72                    Silver Terrace        10g     District 10 - Southeast
# 50                   Mission Terrace        10h     District 10 - Southeast
# 27                     Hunters Point        10j     District 10 - Southeast
# 89                   Bayview Heights        10k     District 10 - Southeast
# 88                 Candlestick Point        10m     District 10 - Southeast
# 90                  Little Hollywood        10n     District 10 - Southeast
# 24                  Golden Gate Park        12a                        None
# 67                          Presidio        12b                        None
# 84                      Lincoln Park        12c                        None
# 6                   Central Richmond         1a      District 1 - Northwest
# 33                    Inner Richmond         1b      District 1 - Northwest
# 35      Jordan Park / Laurel Heights         1c      District 1 - Northwest
# 36                       Lake Street         1d      District 1 - Northwest
# 59                    Outer Richmond         1e      District 1 - Northwest
# 71                         Sea Cliff         1f      District 1 - Northwest
# 40                     Lone Mountain         1g      District 1 - Northwest
# 23               Golden Gate Heights         2a   District 2 - Central West
# 58                    Outer Parkside         2b   District 2 - Central West
# 60                      Outer Sunset         2c   District 2 - Central West
# 62                          Parkside         2d   District 2 - Central West
# 7                     Central Sunset         2e   District 2 - Central West
# 34                      Inner Sunset         2f   District 2 - Central West
# 32                    Inner Parkside         2g   District 2 - Central West
# 38                        Lake Shore         3a      District 3 - Southwest
# ..                               ...        ...                         ...
# 14                   Duboce Triangle         5j        District 5 - Central
# 15   Eureka Valley / Dolores Heights         5k        District 5 - Central
# 49                   Mission Dolores         5m        District 5 - Central
# 1                         Anza Vista         6a  District 6 - Central North
# 26                      Hayes Valley         6b  District 6 - Central North
# 81                  Western Addition         6d  District 6 - Central North
# 0                       Alamo Square         6e  District 6 - Central North
# 54                   North Panhandle         6f  District 6 - Central North
# 41             Lower Pacific Heights         6f  District 6 - Central North
# 42                            Marina         7a          District 7 - North
# 61                   Pacific Heights         7b          District 7 - North
# 68                  Presidio Heights         7c          District 7 - North
# 10                        Cow Hollow         7d          District 7 - North
# 13                          Downtown         8a      District 8 - Northeast
# 17  Financial District/Barbary Coast         8b      District 8 - Northeast
# 91                          Nob Hill         8c      District 8 - Northeast
# 53                       North Beach         8d      District 8 - Northeast
# 69                      Russian Hill         8e      District 8 - Northeast
# 78             Van Ness/Civic Center         8f      District 8 - Northeast
# 76                    Telegraph Hill         8g      District 8 - Northeast
# 55                  North Waterfront         8h      District 8 - Northeast
# 86                        Tenderloin         8j      District 8 - Northeast
# 4                     Bernal Heights         9a   District 9 - Central East
# 31                     Inner Mission         9c   District 9 - Central East
# 48                       Mission Bay         9d   District 9 - Central East
# 66                      Potrero Hill         9e   District 9 - Central East
# 73                   South of Market         9f   District 9 - Central East
# 18                       Yerba Buena         9g   District 9 - Central East
# 46                       South Beach         9h   District 9 - Central East
# 87       Central Waterfront/Dogpatch         9j   District 9 - Central East
#
#                                              geometry
# 3   MULTIPOLYGON (((-122.38759 37.75026, -122.3874...
# 11  MULTIPOLYGON (((-122.42470 37.71022, -122.4245...
# 16  MULTIPOLYGON (((-122.42558 37.73148, -122.4239...
# 57  MULTIPOLYGON (((-122.44562 37.71197, -122.4489...
# 79  MULTIPOLYGON (((-122.42335 37.70925, -122.4241...
# 65  MULTIPOLYGON (((-122.40559 37.73329, -122.4045...
# 72  MULTIPOLYGON (((-122.40676 37.73525, -122.4059...
# 50  MULTIPOLYGON (((-122.42828 37.73196, -122.4319...
# 27  MULTIPOLYGON (((-122.38702 37.74705, -122.3870...
# 89  MULTIPOLYGON (((-122.39179 37.72044, -122.3924...
# 88  MULTIPOLYGON (((-122.38339 37.72034, -122.3833...
# 90  MULTIPOLYGON (((-122.40531 37.70837, -122.4051...
# 24  MULTIPOLYGON (((-122.45474 37.77466, -122.4541...
# 67  MULTIPOLYGON (((-122.47695 37.81098, -122.4766...
# 84  MULTIPOLYGON (((-122.49363 37.78761, -122.4936...
# 6   MULTIPOLYGON (((-122.49168 37.77212, -122.4916...
# 33  MULTIPOLYGON (((-122.46524 37.77333, -122.4717...
# 35  MULTIPOLYGON (((-122.44688 37.78713, -122.4460...
# 36  MULTIPOLYGON (((-122.46364 37.78871, -122.4635...
# 59  MULTIPOLYGON (((-122.49238 37.78168, -122.4922...
# 71  MULTIPOLYGON (((-122.48505 37.79037, -122.4849...
# 40  MULTIPOLYGON (((-122.45474 37.77466, -122.4585...
# 23  MULTIPOLYGON (((-122.47098 37.75856, -122.4707...
# 58  MULTIPOLYGON (((-122.51054 37.75075, -122.4950...
# 60  MULTIPOLYGON (((-122.51257 37.76398, -122.4960...
# 62  MULTIPOLYGON (((-122.49108 37.73724, -122.4913...
# 7   MULTIPOLYGON (((-122.47747 37.76531, -122.4764...
# 34  MULTIPOLYGON (((-122.47334 37.75546, -122.4732...
# 32  MULTIPOLYGON (((-122.47300 37.75065, -122.4728...
# 38  MULTIPOLYGON (((-122.47514 37.73028, -122.4759...
# ..                                                ...
# 14  MULTIPOLYGON (((-122.42895 37.76750, -122.4310...
# 15  MULTIPOLYGON (((-122.42879 37.76739, -122.4279...
# 49  MULTIPOLYGON (((-122.42260 37.77084, -122.4214...
# 1   MULTIPOLYGON (((-122.44746 37.77986, -122.4473...
# 26  MULTIPOLYGON (((-122.42609 37.76976, -122.4357...
# 81  MULTIPOLYGON (((-122.42366 37.77966, -122.4268...
# 0   MULTIPOLYGON (((-122.42948 37.77510, -122.4310...
# 54  MULTIPOLYGON (((-122.43774 37.77404, -122.4392...
# 41  MULTIPOLYGON (((-122.42340 37.78734, -122.4250...
# 42  MULTIPOLYGON (((-122.44597 37.80551, -122.4452...
# 61  MULTIPOLYGON (((-122.42322 37.79587, -122.4220...
# 68  MULTIPOLYGON (((-122.46364 37.78873, -122.4636...
# 10  MULTIPOLYGON (((-122.44782 37.80086, -122.4471...
# 13  MULTIPOLYGON (((-122.40343 37.78764, -122.4045...
# 17  MULTIPOLYGON (((-122.39307 37.79572, -122.3930...
# 91  MULTIPOLYGON (((-122.40876 37.79772, -122.4076...
# 53  MULTIPOLYGON (((-122.41729 37.80507, -122.4104...
# 69  MULTIPOLYGON (((-122.42169 37.80795, -122.4216...
# 78  MULTIPOLYGON (((-122.41147 37.78130, -122.4125...
# 76  MULTIPOLYGON (((-122.41042 37.80592, -122.4072...
# 55  MULTIPOLYGON (((-122.40787 37.80821, -122.4076...
# 86  MULTIPOLYGON (((-122.40895 37.78329, -122.4102...
# 4   MULTIPOLYGON (((-122.40375 37.74919, -122.4046...
# 31  MULTIPOLYGON (((-122.41830 37.74801, -122.4184...
# 48  MULTIPOLYGON (((-122.39942 37.77356, -122.3978...
# 66  MULTIPOLYGON (((-122.39434 37.76658, -122.3935...
# 73  MULTIPOLYGON (((-122.40118 37.77834, -122.4009...
# 18  MULTIPOLYGON (((-122.39430 37.78378, -122.3942...
# 46  MULTIPOLYGON (((-122.39120 37.79578, -122.3924...
# 87  MULTIPOLYGON (((-122.37596 37.75094, -122.3826...
#
# [92 rows x 4 columns]

# %% [markdown]
# ### Create a function the returns json_data for the year selected by the user

# %%
# Create a function the returns json_data for the year selected by the user
def json_data(selectedYear):
    yr = selectedYear
    
    # Pull selected year from neighborhood summary data
    df_yr = neighborhood_data[neighborhood_data['year'] == yr]
    
    # Merge the GeoDataframe object (sf) with the neighborhood summary data (neighborhood)
    merged = pd.merge(sf, df_yr, on='subdist_no', how='left')
    
    # Fill the null values
    values = {'year': yr, 'sale_price_count': 0, 'sale_price_mean': 0, 'sale_price_median': 0,
              'sf_mean': 0, 'price_sf_mean': 0, 'min_income': 0}
    merged = merged.fillna(value=values)
    
    # Bokeh uses geojson formatting, representing geographical features, with json
    # Convert to json
    merged_json = json.loads(merged.to_json())
    
    # Convert to json preferred string-like object 
    json_data = json.dumps(merged_json)
    return json_data
